# %%
capex = [800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2050, 2100, 2150, 2200, 2250, 2300, 2350, 2400, 2450, 2500, 2550, 2600, 2650, 2700, 2750, 2800, 2850, 2900, 2950, 3000]
npv = [2501.95, 2451.95, 2401.95, 2351.95, 2301.95, 2251.95, 2201.95, 2151.95, 2101.95, 2051.95, 2001.95, 1951.95, 1901.95, 1851.95, 1801.95, 1751.95, 1701.95, 1651.95, 1601.95, 1551.95, 1501.95, 1451.95, 1401.95, 1351.95, 1301.95, 1251.95, 1201.95, 1151.95, 1101.95, 1051.95, 1001.95, 951.95, 901.95, 851.95, 801.95, 751.95, 701.95, 651.95, 601.95, 551.95, 501.95, 451.95, 401.95, 351.95, 301.95]


import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.plot(capex, npv, marker='o', linestyle='-', color='b')
plt.title(r'NPV vs CAPEX', fontsize=12)
plt.xlabel(r'CAPEX [Million EUR]', fontsize=12)
plt.ylabel(r'NPV [Million EUR]', fontsize=12)
plt.axhline(0, color='r', linestyle='--', label='NPV = 0')
plt.grid()
plt.legend()
plt.savefig('./Report/figures/4_npv_vs_capex_OPT.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
capex_lcoe = [800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2050, 2100, 2150, 2200, 2250, 2300, 2350, 2400, 2450, 2500, 2550, 2600, 2650, 2700, 2750, 2800, 2850, 2900, 2950, 3000]
lcoe_capex = [49.80, 50.86, 51.93, 52.99, 54.06, 55.12, 56.18, 57.25, 58.31, 59.37, 60.44, 61.50, 62.56, 63.63, 64.69, 65.75, 66.82, 67.88, 68.94, 70.01, 71.07, 72.13, 73.20, 74.26, 75.33, 76.39, 77.45, 78.52, 79.58, 80.64, 81.71, 82.77, 83.83, 84.90, 85.96, 87.02, 88.09, 89.15, 90.21, 91.28, 92.34, 93.40, 94.47, 95.53, 96.60]

plt.figure(figsize=(6, 6))
plt.plot(capex_lcoe, lcoe_capex, marker='o', linestyle='-', color='b')
plt.title(r'$LCOE_{en}$ vs $\mathrm{CAPEX}$', fontsize=12)
plt.xlabel(r'$\mathrm{CAPEX}$ [Million EUR]', fontsize=12)
plt.ylabel(r'$LCOE_{en}$ [EUR/MWh]', fontsize=12)
plt.axhline(100, color='r', linestyle='--', label=r'$LCOE_{en}$ 100 EUR/MWh')
plt.legend()
plt.grid()
plt.savefig('./Report/figures/4_LCOE_vs_capex_OPT.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
discount_rates = [0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025, 0.0275, 0.03, 0.0325, 0.035, 0.0375, 0.04, 0.0425, 0.045, 0.0475, 0.05, 0.0525, 0.055, 0.0575, 0.06, 0.0625, 0.065, 0.0675, 0.07, 0.0725, 0.075, 0.0775, 0.08, 0.0825, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1]
npv_discount = [5147.09, 4736.98, 4363.05, 4021.42, 3708.67, 3421.79, 3158.12, 2915.29, 2691.22, 2484.06, 2292.16, 2114.05, 1948.44, 1794.17, 1650.20, 1515.61, 1389.57, 1271.34, 1160.25, 1055.71, 957.19, 864.19, 776.27, 693.06, 614.18, 539.32, 468.18, 400.50, 336.03, 274.55, 215.86, 159.78, 106.14, 54.78, 5.56, -41.65, -86.97, -130.51, -172.37]


plt.figure(figsize=(6, 6))
plt.plot(discount_rates, npv_discount, marker='o', linestyle='-', color='b')
plt.title(r'$NPV$ vs Discount Rate', fontsize=12)
plt.xlabel(r'Discount Rate [%]', fontsize=12)
plt.ylabel(r'$NPV$ [Millions EUR]', fontsize=12)
plt.axhline(0, color='r', linestyle='--', label=r'NPV = 0')
plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])
plt.legend()
plt.grid()
plt.savefig('./Report/figures/4_NPV_vs_discount_OPT.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Simo\AppData\Local\Temp\ipykernel_2484\3067656601.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])

# %%
discount_rates_lcoe = [0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025, 0.0275, 0.03, 0.0325, 0.035, 0.0375, 0.04, 0.0425, 0.045, 0.0475, 0.05, 0.0525, 0.055, 0.0575, 0.06, 0.0625, 0.065, 0.0675, 0.07, 0.0725, 0.075, 0.0775, 0.08, 0.0825, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1]
lcoe_discount = [59.43, 60.23, 61.06, 61.93, 62.83, 63.77, 64.73, 65.72, 66.75, 67.80, 68.87, 69.98, 71.10, 72.26, 73.43, 74.63, 75.84, 77.08, 78.34, 79.61, 80.91, 82.22, 83.54, 84.88, 86.24, 87.61, 88.99, 90.39, 91.80, 93.22, 94.66, 96.10, 97.56, 99.02, 100.50, 101.98, 103.48, 104.98, 106.49]



plt.figure(figsize=(6, 6))
plt.plot(discount_rates_lcoe, lcoe_discount, marker='o', linestyle='-', color='b')
plt.title(r'$LCOE_{en}$ vs Discount Rate', fontsize=12)
plt.xlabel(r'Discount Rate [%]', fontsize=12)
plt.ylabel(r'$LCOE_{en}$ [EUR/MWh]', fontsize=12)
plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])
plt.axhline(100, color='r', linestyle='--', label=r'$LCOE_{en}$ 100 EUR/MWh')
plt.legend()
plt.grid()
plt.savefig('./Report/figures/4_LCOE_vs_discount_OPT.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Simo\AppData\Local\Temp\ipykernel_2484\807983374.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])
