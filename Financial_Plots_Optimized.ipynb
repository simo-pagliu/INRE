# %%
capex = [
    800.0, 850.0, 900.0, 950.0, 1000.0, 1050.0, 1100.0, 1150.0, 1200.0, 1250.0,
    1300.0, 1350.0, 1400.0, 1450.0, 1500.0, 1550.0, 1600.0, 1650.0, 1700.0, 1750.0,
    1800.0, 1850.0, 1900.0, 1950.0, 2000.0, 2050.0, 2100.0, 2150.0, 2200.0, 2250.0,
    2300.0, 2350.0, 2400.0, 2450.0, 2500.0, 2550.0, 2600.0, 2650.0, 2700.0, 2750.0,
    2800.0, 2850.0, 2900.0, 2950.0, 3000.0
]

npv = [
    687.36, 637.36, 587.36, 537.36, 487.36, 437.36, 387.36, 337.36, 287.36, 237.36,
    187.36, 137.36, 87.36, 37.36, -12.64, -62.64, -112.64, -162.64, -212.64, -262.64,
    -312.64, -362.64, -412.64, -462.64, -512.64, -562.64, -612.64, -662.64, -712.64, -762.64,
    -812.64, -862.64, -912.64, -962.64, -1012.64, -1062.64, -1112.64, -1162.64, -1212.64, -1262.64,
    -1312.64, -1362.64, -1412.64, -1462.64, -1512.64
]

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.plot(capex, npv, marker='o', linestyle='-', color='b')
plt.title(r'NPV vs CAPEX', fontsize=12)
plt.xlabel(r'CAPEX [Million EUR]', fontsize=12)
plt.ylabel(r'NPV [Million EUR]', fontsize=12)
plt.axhline(0, color='r', linestyle='--', label='NPV = 0')
plt.grid()
plt.savefig('./Report/figures/4_npv_vs_capex_OPT.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
capex = [
    800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750,
    1800, 1850, 1900, 1950, 2000, 2050, 2100, 2150, 2200, 2250, 2300, 2350, 2400, 2450, 2500, 2550, 2600, 2650, 2700, 2750,
    2800, 2850, 2900, 2950, 3000
]

lcoe = [
    89.89, 91.73, 93.58, 95.42, 97.27, 99.11, 100.96, 102.80, 104.65, 106.49, 108.34, 110.18, 112.03, 113.87, 115.72, 117.56, 119.41, 121.25, 123.10, 124.95,
    126.79, 128.64, 130.48, 132.33, 134.17, 136.02, 137.86, 139.71, 141.55, 143.40, 145.24, 147.09, 148.93, 150.78, 152.62, 154.47, 156.31, 158.16, 160.00, 161.85,
    163.69, 165.54, 167.39, 169.23, 171.08
]

plt.figure(figsize=(6, 6))
plt.plot(capex, lcoe, marker='o', linestyle='-', color='b')
plt.title(r'$LCOE_{en}$ vs $\mathrm{CAPEX}$', fontsize=12)
plt.xlabel(r'$\mathrm{CAPEX}$ [Million EUR]', fontsize=12)
plt.ylabel(r'$LCOE_{en}$ [EUR/MWh]', fontsize=12)
plt.axhline(115, color='r', linestyle='--', label=r'$LCOE_{en}$ 115 EUR/MWh')
plt.legend()
plt.grid()
plt.savefig('./Report/figures/4_LCOE_vs_capex_OPT.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
discount_rates = [
    0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025, 0.0275, 0.03, 0.0325, 0.035, 0.0375, 0.04, 0.0425, 0.045, 0.0475, 0.05, 0.0525, 0.055, 0.0575, 0.06, 0.0625, 0.065, 0.0675, 0.07, 0.0725, 0.075, 0.0775, 0.08, 0.0825, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1
]

npv_discount = [
    1844.56, 1528.58, 1243.82, 986.78, 754.40, 543.97, 353.11, 179.70, 21.90, -121.95, -253.30, -373.43, -483.49, -584.49, -677.33, -762.82, -841.67, -914.52, -981.93, -1044.42, -1102.43, -1156.38, -1206.62, -1253.49, -1297.27, -1338.24, -1376.63, -1412.66, -1446.52, -1478.38, -1508.40, -1536.74, -1563.51, -1588.83, -1612.82, -1635.57, -1657.17, -1677.71, -1697.25
]


plt.figure(figsize=(6, 6))
plt.plot(discount_rates, npv_discount, marker='o', linestyle='-', color='b')
plt.title(r'$NPV$ vs Discount Rate', fontsize=12)
plt.xlabel(r'Discount Rate [%]', fontsize=12)
plt.ylabel(r'$NPV$ [Millions EUR]', fontsize=12)
plt.axhline(0, color='r', linestyle='--', label=r'NPV = 0')
plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])
plt.legend()
plt.grid()
plt.savefig('./Report/figures/4_NPV_vs_discount_OPT.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Simo\AppData\Local\Temp\ipykernel_8908\1432641599.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])

# %%
discount_rates_lcoe = [
    0.005, 0.0075, 0.01, 0.0125, 0.015, 0.0175, 0.02, 0.0225, 0.025, 0.0275, 0.03, 0.0325, 0.035, 0.0375, 0.04, 0.0425, 0.045, 0.0475, 0.05, 0.0525, 0.055, 0.0575, 0.06, 0.0625, 0.065, 0.0675, 0.07, 0.0725, 0.075, 0.0775, 0.08, 0.0825, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1
]

lcoe_discount = [
    90.23, 92.93, 95.73, 98.63, 101.63, 104.72, 107.89, 111.16, 114.50, 117.92, 121.41, 124.97, 128.60, 132.29, 136.03, 139.82, 143.67, 147.56, 151.49, 155.46, 159.46, 163.50, 167.56, 171.66, 175.77, 179.91, 184.06, 188.24, 192.43, 196.63, 200.85, 205.07, 209.31, 213.56, 217.81, 222.07, 226.34, 230.61, 234.89
]



plt.figure(figsize=(6, 6))
plt.plot(discount_rates_lcoe, lcoe_discount, marker='o', linestyle='-', color='b')
plt.title(r'$LCOE_{en}$ vs Discount Rate', fontsize=12)
plt.xlabel(r'Discount Rate [%]', fontsize=12)
plt.ylabel(r'$LCOE_{en}$ [EUR/MWh]', fontsize=12)
plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])
plt.axhline(115, color='r', linestyle='--', label=r'$LCOE_{en}$ 115 EUR/MWh')
plt.legend()
plt.grid()
plt.savefig('./Report/figures/4_LCOE_vs_discount_OPT.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Simo\AppData\Local\Temp\ipykernel_8908\3845742738.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])
